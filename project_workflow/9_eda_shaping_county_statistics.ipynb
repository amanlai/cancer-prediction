# %% [markdown]
# # County Statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
counties_2019 = pd.read_csv("data/raw/county_2019.csv")
county_amer_com_surv = pd.read_csv("data/raw/county_info_openintro.csv")
counties_2019.head()
# Out:
#      state            name  fips  age_over_18  age_over_18_moe  age_over_65  \
# 0  Alabama  Autauga County  1001         76.2              0.1         15.0
# 1  Alabama  Baldwin County  1003         78.3              NaN         20.0
# 2  Alabama  Barbour County  1005         79.1              0.1         18.6
# 3  Alabama     Bibb County  1007         79.4              0.2         15.9
# 4  Alabama   Blount County  1009         76.8              0.1         17.9
#
#    age_over_65_moe  age_over_85  age_over_85_moe  age_under_5  ...  \
# 0              0.2          1.6              0.3          5.8  ...
# 1              0.1          1.9              0.3          5.5  ...
# 2              0.1          1.6              0.4          5.3  ...
# 3              0.3          2.0              0.7          5.8  ...
# 4              0.2          1.8              0.3          5.9  ...
#
#    uninsured_under_19  uninsured_under_19_moe  uninsured_under_6  \
# ...

# %%
counties_2019.columns
# Out:
# Index(['state', 'name', 'fips', 'age_over_18', 'age_over_18_moe',
#        'age_over_65', 'age_over_65_moe', 'age_over_85', 'age_over_85_moe',
#        'age_under_5', 'age_under_5_moe', 'asian', 'asian_moe',
#        'avg_family_size', 'avg_family_size_moe', 'bachelors', 'bachelors_moe',
#        'black', 'black_moe', 'hispanic', 'hispanic_moe',
#        'household_has_broadband', 'household_has_broadband_moe',
#        'household_has_computer', 'household_has_computer_moe',
#        'household_has_smartphone', 'household_has_smartphone_moe',
#        'households', 'households_moe', 'households_speak_asian_or_pac_isl',
#        'households_speak_asian_or_pac_isl_moe',
#        'households_speak_limited_english',
#        'households_speak_limited_english_moe', 'households_speak_other',
#        'households_speak_other_moe', 'households_speak_other_indo_euro_lang',
#        'households_speak_other_indo_euro_lang_moe', 'households_speak_spanish',
# ...

# %%
county_amer_com_surv.head()
# Out:
#              name    state   pop2000  pop2010   pop2017  pop_change  poverty  \
# 0  Autauga County  Alabama   43671.0    54571   55504.0        1.48     13.7
# 1  Baldwin County  Alabama  140415.0   182265  212628.0        9.19     11.8
# 2  Barbour County  Alabama   29038.0    27457   25270.0       -6.22     27.2
# 3     Bibb County  Alabama   20826.0    22915   22668.0        0.73     15.2
# 4   Blount County  Alabama   51024.0    57322   58013.0        0.68     15.6
#
#    homeownership  multi_unit  unemployment_rate metro    median_edu  \
# 0           77.5         7.2               3.86   yes  some_college
# 1           76.7        22.6               3.99   yes  some_college
# 2           68.0        11.1               5.90    no    hs_diploma
# 3           82.9         6.6               4.39   yes    hs_diploma
# 4           82.0         3.7               4.02   yes    hs_diploma
#
#    per_capita_income  median_hh_income smoking_ban
# ...

# %%
county_fips = counties_2019[["name", "fips", "age_over_65"]]
county_fips.head()
# Out:
#              name  fips  age_over_65
# 0  Autauga County  1001         15.0
# 1  Baldwin County  1003         20.0
# 2  Barbour County  1005         18.6
# 3     Bibb County  1007         15.9
# 4   Blount County  1009         17.9

# %%
print(county_fips.shape)
print(county_amer_com_surv.shape)
# Out:
# (3142, 3)
# (3142, 15)

# %%
np.mean(county_fips["name"] == county_amer_com_surv["name"]) #looks like these counties aren't quite exactly matched.
# Out:
# 0.9936346276257161

# %%
county_fips[county_fips["name"] != county_amer_com_surv["name"]]
# Out:
#                                    name   fips  age_over_65
# 76            Hoonah-Angoon Census Area   2105         20.5
# 81                 Kusilvak Census Area   2158          5.5
# 82           Lake and Peninsula Borough   2164          7.8
# 83            Matanuska-Susitna Borough   2170         11.3
# 84                     Nome Census Area   2180          7.0
# 85                  North Slope Borough   2185          6.9
# 86             Northwest Arctic Borough   2188          7.5
# 87                   Petersburg Borough   2195         22.0
# 88    Prince of Wales-Hyder Census Area   2198         16.0
# 89               Sitka City and Borough   2220         15.2
# 90                 Skagway Municipality   2230         11.7
# 91      Southeast Fairbanks Census Area   2240         13.6
# 92           Valdez-Cordova Census Area   2261         12.3
# 93            Wrangell City and Borough   2275         22.7
# 2412               Oglala Lakota County  46102          6.8
# ...

# %%
county_amer_com_surv[county_amer_com_surv["name"] != county_fips["name"]]
# Out:
#                                    name         state  pop2000  pop2010  \
# 76            Hoonah Angoon Census Area        Alaska   3436.0     2150
# 81           Lake and Peninsula Borough        Alaska   1823.0     1631
# 82            Matanuska-Susitna Borough        Alaska  59322.0    88995
# 83                     Nome Census Area        Alaska   9196.0     9492
# 84                  North Slope Borough        Alaska   7385.0     9430
# 85             Northwest Arctic Borough        Alaska   7208.0     7523
# 86                   Petersburg Borough        Alaska   6684.0     3815
# 87    Prince of Wales-Hyder Census Area        Alaska   6146.0     5559
# 88               Sitka City and Borough        Alaska   8835.0     8881
# 89                              Skagway        Alaska      NaN      968
# 90      Southeast Fairbanks Census Area        Alaska   6174.0     7029
# 91           Valdez-Cordova Census Area        Alaska  10195.0     9636
# ...

# %%
# since these two county lists are identical except for punctiation, we will concat them rather than left join.
county_data = pd.concat([county_fips, county_amer_com_surv.drop(columns = "name")], axis = 1)
county_data
# Out:
#                    name   fips  age_over_65    state   pop2000  pop2010  \
# 0        Autauga County   1001         15.0  Alabama   43671.0    54571
# 1        Baldwin County   1003         20.0  Alabama  140415.0   182265
# 2        Barbour County   1005         18.6  Alabama   29038.0    27457
# 3           Bibb County   1007         15.9  Alabama   20826.0    22915
# 4         Blount County   1009         17.9  Alabama   51024.0    57322
# ...                 ...    ...          ...      ...       ...      ...
# 3137  Sweetwater County  56037         11.4  Wyoming   37613.0    43806
# 3138       Teton County  56039         14.0  Wyoming   18251.0    21294
# 3139       Uinta County  56041         13.0  Wyoming   19742.0    21118
# 3140    Washakie County  56043         21.1  Wyoming    8289.0     8533
# 3141      Weston County  56045         19.4  Wyoming    6644.0     7208
#
#        pop2017  pop_change  poverty  homeownership  multi_unit  \
# ...

# %%
county_data.to_csv("data/processed/county_information.csv", index = False)
